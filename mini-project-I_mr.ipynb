# %% [markdown]
# # Mini-Project I
# During this project, we will practice handling of complex lists and dictionaries in Python. Plus, we will learn how to work with API documentation. Don't be afraid to search for the information in the [**documentation**](https://api.tfl.gov.uk/swagger/ui/index.html?url=/swagger/docs/v1#!/AccidentStats/AccidentStats_Get).
#
# Let's go to the tasks, we have some parsing to do :)!!

# %%
# import packages we need (remember what packages we used yesterday during the API session)
# IMPORT HERE
import requests as re
import os
from IPython.display import JSON
import numpy as np
from datetime import datetime

# %%
# URL
url = "https://api.tfl.gov.uk/AirQuality"

res = re.get(url)

status_code, result = res.status_code, res.json()
if res.status_code!=200:
    print(f'Bad Status Code {res.status_code}')

    
JSON(result)

# %% [markdown]
# ## Task
# Parse the dictionary and print the AirQuality predictions for tomorrow

# %%
prediction_url=[]
for prediction in result['currentForecast']:
    if prediction['forecastType']=="Future":
        prediction_url.append(prediction['forecastText'])

prediction_url
# Out:
# ['Friday forecast to be dry with periods of sunshine and continued northern air feed. Dry with sunny spells on Saturday.&lt;br/&gt;The expected northerly air flow should ensure a &#39;clean&#39; air feed and good dispersion of any locally produced pollutants.&lt;br/&gt;&lt;br/&gt;Air Pollution is expected to remain &#39;Low&#39; for the following pollutants:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;PM10 Particulate&lt;br/&gt;PM2.5 Particulate&lt;br/&gt;Sulphur Dioxide']

# %% [markdown]
# ## Task
# What are the different modes of transport which are operated by Transfer for London? How many of modes do they have?
#
# Print the list with different modes of transport, plus their count. Example output:
# ```
# [bus, cable-car,.....]
# Number of different modes of transport is: xyz
# ```
#
# We need to search the documentation for correct request.

# %%
url = "https://api.tfl.gov.uk/StopPoint/Meta/Modes"

res = re.get(url)

status_code, result = res.status_code, res.json()
if res.status_code!=200:
    print(f'Bad Status Code {res.status_code}')

    
JSON(result)
#res.json()

# %%
mode_url=[]
for mode in result:
    mode_url.append(mode['modeName'])
print('This is the list of the different modes of transport\n')
print(mode_url)
print(f'\nThe amount of different modes of transport is {len(mode_url)}')
# Out:
# This is the list of the different modes of transport
#
# ['bus', 'cable-car', 'coach', 'cycle', 'cycle-hire', 'dlr', 'interchange-keep-sitting', 'interchange-secure', 'national-rail', 'overground', 'replacement-bus', 'river-bus', 'river-tour', 'taxi', 'tflrail', 'tram', 'tube', 'walking']
#
# The amount of different modes of transport is 18

# %% [markdown]
# ## Task
# How many BikePoints in London are operated by Transfor for London? How many docks are in **all** BikePoints? There is the information for empty and full docks for each BikePoint.

# %%
url = "https://api.tfl.gov.uk/BikePoint"

res = re.get(url)

status_code, result = res.status_code, res.json()
if res.status_code!=200:
    print(f'Bad Status Code {res.status_code}')

    
JSON(result)
#res.json()

# %%
#initialize variables
sum_bikepoint=0
sum_nbbikes=0
sum_nbemptydocks=0
sum_nbdocks=0
sum_brokendocks=0

for point in result:
    sum_nbbikes=sum_nbbikes+int(point['additionalProperties'][6]['value'])
    sum_nbemptydocks=sum_nbemptydocks+int(point['additionalProperties'][7]['value'])
    sum_nbdocks=sum_nbdocks+int(point['additionalProperties'][8]['value'])
    
# nbbikes+emptydocks should be equal to nbdocks
# any difference can be attributed to broken docks
sum_brokendocks=sum_brokendocks+(sum_nbdocks-sum_nbemptydocks-sum_nbbikes)

print('How many BikePoints in London are operated by Transfor for London?')
print(len(result))

print('\nHow many docks are in all BikePoints?')
print('\nFor Each BikePoint:')
print('Number of bikes + Number of empty docks equals to Number of docks')
print('any discrepancy can be attributed to broken docks')
print(f'Total Amount of docks= {sum_nbdocks}')
print(f'Total Amount of emtpy docks= {sum_nbemptydocks}') 
print(f'Total Amount of broken docks= {sum_brokendocks}')
# Out:
# How many BikePoints in London are operated by Transfor for London?
# 792
#
# How many docks are in all BikePoints?
#
# For Each BikePoint:
# Number of bikes + Number of empty docks equals to Number of docks
# any discrepancy can be attributed to broken docks
# Total Amount of docks= 21051
# Total Amount of emtpy docks= 10205
# Total Amount of broken docks= 458

# %% [markdown]
# ## Task
# How many tube and bus lines are in London? Print names of all tube lines.

# %%
urlbus = "https://api.tfl.gov.uk/Line/Mode/bus"
urltube = "https://api.tfl.gov.uk/Line/Mode/tube"

res_bus = re.get(urlbus)
res_tube = re.get(urltube)

status_code_bus, result_bus = res_bus.status_code, res_bus.json()
if res_bus.status_code!=200:
    print(f'Bad Status Code {res_bus.status_code}')

status_code_tube, result_tube = res_tube.status_code, res_tube.json()
if res_tube.status_code!=200:
    print(f'Bad Status Code {res_tube.status_code}') 

#JSON(result_bus)
JSON(result_tube)
#res.json()

# %%
tube_lines=[]
for tubes in result_tube:
    tube_lines.append(tubes['name'])
    
print('How many tube lines are in London? ')
print(len(result_tube))

print('How many bus lines are in London? ')
print(len(result_bus))

print('Print names of all tube lines.')
print(tube_lines)
# Out:
# How many tube lines are in London?
# 11
# How many bus lines are in London?
# 679
# Print names of all tube lines.
# ['Bakerloo', 'Central', 'Circle', 'District', 'Hammersmith & City', 'Jubilee', 'Metropolitan', 'Northern', 'Piccadilly', 'Victoria', 'Waterloo & City']

# %% [markdown]
# ## Task
# How many station has `victoria` line?

# %%
url = "https://api.tfl.gov.uk/Line/Victoria/StopPoints"

res = re.get(url)

status_code, result = res.status_code, res.json()
if res.status_code!=200:
    print(f'Bad Status Code {res.status_code}')

    
JSON(result)
#res.json()

# %%
victoria_stations=[]
for stations in result:
    victoria_stations.append(stations['commonName'])
    
print('How many station has victoria line?')
print(len(victoria_stations))
victoria_stations
# Out:
# How many station has victoria line?
# 16
# ['Blackhorse Road Underground Station',
#  'Brixton Underground Station',
#  'Euston Underground Station',
#  'Finsbury Park Underground Station',
#  'Green Park Underground Station',
#  'Highbury & Islington Underground Station',
#  "King's Cross St. Pancras Underground Station",
#  'Oxford Circus Underground Station',
#  'Pimlico Underground Station',
#  'Stockwell Underground Station',
#  'Seven Sisters Underground Station',
#  'Tottenham Hale Underground Station',
#  'Victoria Underground Station',
#  'Vauxhall Underground Station',
#  'Warren Street Underground Station',
#  'Walthamstow Central Underground Station']

# %% [markdown]
# ## Task
# Plan the journey from Heathrow Airport to Tower Bridge using Bus and Tube? Which way is faster? Example output:
# ```
# Planned duration:
# Bus: x minutes
# Tube: y minutes
# ```
#
# We need to search the documentation for correct requests and parameters we need.

# %%
#Airport_lat=51.470020; #Airoirt_long=-0.454295
#Tower_b_lat=51.505554; #Tower_b_long=-0.075278
#Airport_postcode=TW62GA; #Tower_post_code=SE14TW 

#url with postal code
url="https://api.tfl.gov.uk/Journey/JourneyResults/TW62GA/to/SE14TW?mode=bus"
res = re.get(url)
status_code, result = res.status_code, res.json()
if res.status_code!=200:
    print(f'Bad Status Code {res.status_code}')
    
JSON(result)
#res.json()

# %%
duration=[]
for i in np.arange(len(result['journeys'])):
    duration.append(int(result['journeys'][i]['duration']))

print('Planned duration:')
print(f'Bus: {min(duration)} minutes')
# Out:
# Planned duration:
# Bus: 109 minutes

# %%
#Airport_lat=51.470020; #Airoirt_long=-0.454295
#Tower_b_lat=51.505554; #Tower_b_long=-0.075278
#Airport_postcode=TW62GA; #Tower_post_code=SE14TW 

#url with postal code
url="https://api.tfl.gov.uk/Journey/JourneyResults/TW62GA/to/SE14TW?mode=tube"  
res = re.get(url)

status_code, result = res.status_code, res.json()
if res.status_code!=200:
    print(f'Bad Status Code {res.status_code}')
    
JSON(result)
#res.json()

# %%
duration=[]
for i in np.arange(len(result['journeys'])):
    duration.append(int(result['journeys'][i]['duration']))

print('Planned duration:')
print(f'Tube: {min(duration)} minutes')
# Out:
# Planned duration:
# Tube: 92 minutes
